# %%
import pandas as pd
import re
import sys

# %%
pd.set_option('display.max_columns', None)

# %%
file = "AL-10128988-2367.snp.hf.pass.vcf"
bed = "../annotation/genes/repeats_annot.bed"

# %%
def calculate_ALT_AD(row):
    split_AD = row.AD.split(",")[1:]
    split_AD = [int(x) for x in split_AD]
    if row.len_AD > 2:
        max_AD = max(split_AD)
        #max_index = split_AD.index(max(split_AD))
        return max_AD
    else:
        #ALT_AD = row.AD.split(",")[1]
        return split_AD[0]

# %%
def calculate_AD_list(row):
    split_AD = row.AD.split(",")[1:]
    split_AD = [int(x) for x in split_AD]
    max_AD = max(split_AD)
    row.AD_list = split_AD
        #max_index = split_AD.index(max(split_AD))
    return split_AD

# %%
def handle_polymorphism(vcf_df):
    for index, _ in vcf_df[vcf_df.len_AD > 2].iterrows():
        split_AD = vcf_df.loc[index, 'AD'].split(",")[1:]
        split_AD = [int(x) for x in split_AD]
        if max(split_AD)/min(split_AD) > 3:
            max_index = split_AD.index(max(split_AD))
            split_ALT = vcf_df.loc[index, 'ALT'].split(",")
            vcf_df.loc[index, 'ALT'] = split_ALT[max_index]
            vcf_df.loc[index, 'len_AD'] = 2

# %%
handle_polymorphism(test_pmf)

# %%
test_pmf
# Out:
#       #CHROM      POS ID REF ALT       QUAL FILTER  \
# 695  MTB_anc  2626189  .   A   C  101892.61   PASS
# 696  MTB_anc  2626191  .   T   C  101887.04   PASS
#
#                                                   INFO          FORMAT  \
# 695  AC=1,1;AF=0.500,0.500;AN=2;BaseQRankSum=0.789;...  GT:AD:DP:GQ:PL
# 696  AC=1,1;AF=0.500,0.500;AN=2;BaseQRankSum=0.330;...  GT:AD:DP:GQ:PL
#
#                                         sample   AC   af   AN    DP  \
# 695  1/2:0,29,5:34:99:1425,207,120,1218,0,1245  1.0  1.0  0.5  34.0
# 696  1/2:0,29,5:34:99:1425,207,120,1218,0,1245  1.0  1.0  0.5  34.0
#
#      ExcessHet    FS InbreedingCoeff   MQ     QD    SOR   GT      AD    GQ  \
# 695      0.789  34.0          3.0103  0.0  45.58  29.66  1/2  0,29,5  99.0
# 696      0.330  34.0          3.0103  0.0  45.49  36.86  1/2  0,29,5  99.0
#
#                            PL  BaseQRankSum  MQRankSum  ReadPosRankSum  PGT  \
# 695  1425,207,120,1218,0,1245           0.5     0.0160          -0.041  NaN
# 696  1425,207,120,1218,0,1245           0.5     0.0064          -0.041  NaN
#
#      PID   PS  len_AD  REF_AD  ALT_AD  AD_list  gt0  gt1    dp   aF   AF
# 695  NaN  NaN       2     0.0    29.0  [29, 5]    1    2  29.0  0.0  1.0
# 696  NaN  NaN       2     0.0    29.0  [29, 5]    1    2  29.0  0.0  1.0

# %%
def import_VCF42_to_pandas(vcf_file, sep='\t'):
    """
    Script to read vcf 4.2
    - now handle correct allele frequency calculated by summing REF reads + ALT reads instead from DP parameter
    - now retrieve the largest read number for ALT allele frequency in case is a heterozygous SNP (depends on calculate_ALT_AD())
    - now uses dataframe.iterrows() instead dataframe.index
    """
    header_lines = 0
    with open(vcf_file) as f:
        first_line = f.readline().strip()
        next_line = f.readline().strip()
        while next_line.startswith("##"):
            header_lines = header_lines + 1
            #print(next_line)
            next_line = f.readline()
    
    if first_line.endswith('VCFv4.2'):
        
        #Use first line as header
        dataframe = pd.read_csv(vcf_file, sep=sep, skiprows=[header_lines], header=header_lines)
        sample = dataframe.columns[-1]
        dataframe.rename(columns={sample:'sample'}, inplace=True)
        
        for index, data_row in dataframe.iterrows():
            info_fields = re.findall(r';*([a-zA-Z]{1,20})=', data_row.INFO)
            info_values = re.findall(r'-?\d+\.?\d*e?[+-]?\d{0,2}', data_row.INFO)
            
            format_fields = data_row['FORMAT'].split(":")
            format_values = data_row['sample'].split(":")
                                    
            for ifield, ivalue in zip(info_fields,info_values):
                dataframe.loc[index,ifield] = ivalue
                
            for ffield, fvalue in zip(format_fields,format_values):
                dataframe.loc[index,ffield] = fvalue
            
            
        dataframe.rename(columns={'AF':'af'}, inplace=True)
        
        dataframe['len_AD'] = dataframe['AD'].str.split(",").str.len()
        dataframe['REF_AD'] = dataframe['AD'].str.split(",").str[0]
        #dataframe['ALT_AD'] = dataframe['AD'].str.split(",").str[1]
        
        dataframe['ALT_AD'] = dataframe.apply(calculate_ALT_AD, axis=1)
        dataframe[['gt0','gt1']] = dataframe['GT'].str.split(r'[/|\|]', expand=True)
        
        handle_polymorphism(dataframe)
                
        to_float = ['QUAL', 'AC', 'af', 'AN', 'BaseQRankSum', 'DP', 'ExcessHet', 'FS',
       'MLEAC', 'MLEAF', 'MQ', 'MQRankSum', 'QD', 'ReadPosRankSum', 'SOR','GQ','ALT_AD', 'REF_AD']
        
        to_int = ['POS', 'len_AD', 'gt0', 'gt1']
        
        to_str = ['#CHROM','REF','ALT', 'FILTER']
        
        for column in dataframe.columns:
            if column in to_float:
                dataframe[column] = dataframe[column].astype(float)
                
        for column in dataframe.columns:
            if column in to_int:
                dataframe[column] = dataframe[column].astype(int)
                
        for column in dataframe.columns:
            if column in to_str:
                dataframe[column] = dataframe[column].astype(str)
                
        dataframe['dp'] = (dataframe['REF_AD'] + dataframe['ALT_AD'])
        dataframe['aF'] = dataframe['REF_AD']/dataframe['dp']
        dataframe['AF'] = dataframe['ALT_AD']/dataframe['dp']
        

                
    else:
        print("This vcf file is not v4.2")
        sys.exit(1)
           
    return dataframe

# %%
df = import_VCF42_to_pandas(file)

# %%
df.head()
# Out:
#     #CHROM    POS ID REF ALT       QUAL FILTER  \
# 0  MTB_anc   1277  .   C   A   12726.43   PASS
# 1  MTB_anc   2532  .   C   T   71031.72   PASS
# 2  MTB_anc   9143  .   C   T  128501.72   PASS
# 3  MTB_anc  13460  .   G   A  129292.72   PASS
# 4  MTB_anc  14251  .   G   A   68528.18   PASS
#
#                                                 INFO          FORMAT  \
# 0  AC=2;AF=1.00;AN=2;DP=187;ExcessHet=0.0006;FS=0...  GT:AD:DP:GQ:PL
# 1  AC=2;AF=1.00;AN=2;BaseQRankSum=1.83;DP=86;Exce...  GT:AD:DP:GQ:PL
# 2  AC=2;AF=1.00;AN=2;DP=57;ExcessHet=3.0103;FS=0....  GT:AD:DP:GQ:PL
# 3  AC=2;AF=1.00;AN=2;BaseQRankSum=1.78;DP=45;Exce...  GT:AD:DP:GQ:PL
# 4  AC=2;AF=1.00;AN=2;BaseQRankSum=-1.716e+00;DP=3...  GT:AD:DP:GQ:PL
#
#                         sample   AC   af   AN     DP  ExcessHet   FS  \
# 0  1/1:0,187:187:99:7003,561,0  2.0  1.0  2.0  187.0     0.0006  0.0
# 1    1/1:0,86:86:99:2878,257,0  2.0  1.0  2.0   86.0     3.0103  0.0
# 2    1/1:0,57:57:99:2071,170,0  2.0  1.0  2.0   57.0     3.0103  0.0
# 3    1/1:0,45:45:99:1791,135,0  2.0  1.0  2.0   45.0     3.0103  0.0
# 4     1/1:0,33:33:98:1174,98,0  2.0  1.0  2.0   33.0     0.0000  0.0
#
#   InbreedingCoeff    MQ     QD    SOR   GT     AD    GQ          PL  \
# 0          1.0000  60.0  25.36  0.791  1/1  0,187  99.0  7003,561,0
# 1         -0.0000  60.0  34.33  0.159  1/1   0,86  99.0  2878,257,0
# 2         -0.0000  60.0  25.00  0.956  1/1   0,57  99.0  2071,170,0
# 3         -0.0000  60.0  34.57  0.307  1/1   0,45  99.0  1791,135,0
# 4          1.0000  60.0  33.31  1.286  1/1   0,33  98.0   1174,98,0
#
#    BaseQRankSum  MQRankSum  ReadPosRankSum  PGT  PID   PS  len_AD  REF_AD  \
# 0           NaN        NaN             NaN  NaN  NaN  NaN       2     0.0
# 1         1.830        0.0           0.316  NaN  NaN  NaN       2     0.0
# 2           NaN        NaN             NaN  NaN  NaN  NaN       2     0.0
# 3         1.780        0.0           0.919  NaN  NaN  NaN       2     0.0
# 4        -1.716        0.0           0.067  NaN  NaN  NaN       2     0.0
#
#    ALT_AD  gt0  gt1     dp   aF   AF
# 0   187.0    1    1  187.0  0.0  1.0
# 1    86.0    1    1   86.0  0.0  1.0
# 2    57.0    1    1   57.0  0.0  1.0
# 3    45.0    1    1   45.0  0.0  1.0
# 4    33.0    1    1   33.0  0.0  1.0

# %%
df[(df.POS == 2626189) | (df.POS == 2626191)]
# Out:
#       #CHROM      POS ID REF ALT       QUAL FILTER  \
# 695  MTB_anc  2626189  .   A   C  101892.61   PASS
# 696  MTB_anc  2626191  .   T   C  101887.04   PASS
#
#                                                   INFO          FORMAT  \
# 695  AC=1,1;AF=0.500,0.500;AN=2;BaseQRankSum=0.789;...  GT:AD:DP:GQ:PL
# 696  AC=1,1;AF=0.500,0.500;AN=2;BaseQRankSum=0.330;...  GT:AD:DP:GQ:PL
#
#                                         sample   AC   af   AN    DP  \
# 695  1/2:0,29,5:34:99:1425,207,120,1218,0,1245  1.0  1.0  0.5  34.0
# 696  1/2:0,29,5:34:99:1425,207,120,1218,0,1245  1.0  1.0  0.5  34.0
#
#      ExcessHet    FS InbreedingCoeff   MQ     QD    SOR   GT      AD    GQ  \
# 695      0.789  34.0          3.0103  0.0  45.58  29.66  1/2  0,29,5  99.0
# 696      0.330  34.0          3.0103  0.0  45.49  36.86  1/2  0,29,5  99.0
#
#                            PL  BaseQRankSum  MQRankSum  ReadPosRankSum  PGT  \
# 695  1425,207,120,1218,0,1245           0.5     0.0160          -0.041  NaN
# 696  1425,207,120,1218,0,1245           0.5     0.0064          -0.041  NaN
#
#      PID   PS  len_AD  REF_AD  ALT_AD  gt0  gt1    dp   aF   AF
# 695  NaN  NaN       2     0.0    29.0    1    2  29.0  0.0  1.0
# 696  NaN  NaN       2     0.0    29.0    1    2  29.0  0.0  1.0

# %%
df.columns
# Out:
# Index(['#CHROM', 'POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT',
#        'sample', 'AC', 'af', 'AN', 'DP', 'ExcessHet', 'FS', 'InbreedingCoeff',
#        'MQ', 'QD', 'SOR', 'GT', 'AD', 'GQ', 'PL', 'BaseQRankSum', 'MQRankSum',
#        'ReadPosRankSum', 'PGT', 'PID', 'PS', 'len_AD', 'REF_AD', 'ALT_AD',
#        'AD_list', 'gt0', 'gt1', 'dp', 'aF', 'AF'],
#       dtype='object')

# %%
for i in df.AD_list.values:
    if len(i) > 1:
        print(i)
        print(max(i))
# Out:
# [29, 5]
# 29
# [29, 5]
# 29

# %%
def add_window_distance(vcf_df, window_size=10):
    """
    Add a column indicating the maximum number of SNPs in a windows of 10
    """
    list_pos = vcf_df.POS.to_list() #all positions
    set_pos = set(list_pos) #to set for later comparing
    max_pos = max(vcf_df.POS.to_list()) #max to iter over positions (independent from reference)

    all_list = list(range(1, max_pos + 1)) #create a list to slide one by one
    
    df_header = "window_" + str(window_size)

    #Create sets
    set_2 = set()
    set_3 = set()
    set_4 = set()
    set_5 = set()
    
    sets = [set_2, set_3, set_4, set_5]
    
    #Slide over windows
    for i in range(0,max_pos,1):
        window_pos = all_list[i:i+window_size]
        set_window_pos = set(window_pos)
        #How many known positions are in every window for later clasification
        num_conglomerate = set_pos & set_window_pos
        
        if len(num_conglomerate) > 4:
            set_5.update(num_conglomerate)
        elif len(num_conglomerate) == 4:
            set_4.update(num_conglomerate)
        elif len(num_conglomerate) == 3:
            set_3.update(num_conglomerate)
        elif len(num_conglomerate) == 2:
            set_2.update(num_conglomerate)
            
    #Remove positions in a higher number of sets
    for set_num in range(0, len(sets)):
        if set_num < (len(sets) - 1):
            sets[set_num] = sets[set_num] - sets[set_num + 1]
            
    for index, _ in vcf_df.iterrows():
        if vcf_df.loc[index,'POS'] in sets[0]:
            vcf_df.loc[index, df_header] = 2
        elif vcf_df.loc[index,'POS'] in sets[1]:
            vcf_df.loc[index, df_header] = 3
        elif vcf_df.loc[index,'POS'] in sets[2]:
            vcf_df.loc[index, df_header] = 4
        elif vcf_df.loc[index,'POS'] in sets[3]:
            vcf_df.loc[index, df_header] = 5
        else:
            vcf_df.loc[index, df_header] = 1
            
    vcf_df[df_header] = vcf_df[df_header].astype(int)

# %%
add_window_distance(df)

# %%
df.index[df["POS"] == 1480205][0]
# Out:
# 400

# %%
list_pos = df.POS.to_list() #all positions
set_pos = set(list_pos) #to set for later comparing
max_pos = max(df.POS.to_list()) #max to iter over positions (independent from reference)

all_list = list(range(1, max_pos + 1)) #create a list to slide one by one
    
df_header = "window_" + str(30)

df[df_header] = 1
   
#Slide over windows
for i in range(0,max_pos,1):
    window_pos = all_list[i:i+30] #
    
    set_window_pos = set(window_pos)
    
    #How many known positions are in every window for later clasification
    num_conglomerate = set_pos & set_window_pos
    
    if len(num_conglomerate) > 1:
        for i in num_conglomerate:
            #print(i, len(num_conglomerate))
            index = df.index[df["POS"] == i][0]
            if df.loc[index,df_header] < len(num_conglomerate):
                df.loc[index,df_header] = len(num_conglomerate)

# %%
df.head()
# Out:
#     #CHROM    POS ID REF ALT       QUAL FILTER  \
# 0  MTB_anc   1277  .   C   A   12726.43   PASS
# 1  MTB_anc   2532  .   C   T   71031.72   PASS
# 2  MTB_anc   9143  .   C   T  128501.72   PASS
# 3  MTB_anc  13460  .   G   A  129292.72   PASS
# 4  MTB_anc  14251  .   G   A   68528.18   PASS
#
#                                                 INFO          FORMAT  \
# 0  AC=2;AF=1.00;AN=2;DP=187;ExcessHet=0.0006;FS=0...  GT:AD:DP:GQ:PL
# 1  AC=2;AF=1.00;AN=2;BaseQRankSum=1.83;DP=86;Exce...  GT:AD:DP:GQ:PL
# 2  AC=2;AF=1.00;AN=2;DP=57;ExcessHet=3.0103;FS=0....  GT:AD:DP:GQ:PL
# 3  AC=2;AF=1.00;AN=2;BaseQRankSum=1.78;DP=45;Exce...  GT:AD:DP:GQ:PL
# 4  AC=2;AF=1.00;AN=2;BaseQRankSum=-1.716e+00;DP=3...  GT:AD:DP:GQ:PL
#
#                         sample   AC   af   AN     DP  ExcessHet   FS  \
# 0  1/1:0,187:187:99:7003,561,0  2.0  1.0  2.0  187.0     0.0006  0.0
# 1    1/1:0,86:86:99:2878,257,0  2.0  1.0  2.0   86.0     3.0103  0.0
# 2    1/1:0,57:57:99:2071,170,0  2.0  1.0  2.0   57.0     3.0103  0.0
# 3    1/1:0,45:45:99:1791,135,0  2.0  1.0  2.0   45.0     3.0103  0.0
# 4     1/1:0,33:33:98:1174,98,0  2.0  1.0  2.0   33.0     0.0000  0.0
#
#   InbreedingCoeff    MQ     QD    SOR   GT     AD    GQ          PL  \
# 0          1.0000  60.0  25.36  0.791  1/1  0,187  99.0  7003,561,0
# 1         -0.0000  60.0  34.33  0.159  1/1   0,86  99.0  2878,257,0
# 2         -0.0000  60.0  25.00  0.956  1/1   0,57  99.0  2071,170,0
# 3         -0.0000  60.0  34.57  0.307  1/1   0,45  99.0  1791,135,0
# 4          1.0000  60.0  33.31  1.286  1/1   0,33  98.0   1174,98,0
#
#    BaseQRankSum  MQRankSum  ReadPosRankSum  PGT  PID   PS  len_AD  REF_AD  \
# 0           NaN        NaN             NaN  NaN  NaN  NaN       2     0.0
# 1         1.830        0.0           0.316  NaN  NaN  NaN       2     0.0
# 2           NaN        NaN             NaN  NaN  NaN  NaN       2     0.0
# 3         1.780        0.0           0.919  NaN  NaN  NaN       2     0.0
# 4        -1.716        0.0           0.067  NaN  NaN  NaN       2     0.0
#
#    ALT_AD  gt0  gt1     dp   aF   AF  window_10  window_20  window_30
# 0   187.0    1    1  187.0  0.0  1.0          1          1          1
# 1    86.0    1    1   86.0  0.0  1.0          1          1          1
# 2    57.0    1    1   57.0  0.0  1.0          1          1          1
# 3    45.0    1    1   45.0  0.0  1.0          1          1          1
# 4    33.0    1    1   33.0  0.0  1.0          1          1          1

# %%
df[df.window_20 > 6]
# Out:
#       #CHROM      POS ID REF ALT      QUAL FILTER  \
# 394  MTB_anc  1480186  .   C   T   6048.81   PASS
# 395  MTB_anc  1480189  .   C   G   5901.81   PASS
# 396  MTB_anc  1480195  .   G   T   5712.81   PASS
# 397  MTB_anc  1480197  .   G   C   5559.81   PASS
# 398  MTB_anc  1480198  .   T   C   5490.81   PASS
# 399  MTB_anc  1480204  .   C   T   5172.81   PASS
# 400  MTB_anc  1480205  .   G   A   4923.81   PASS
# 700  MTB_anc  2631929  .   C   G  16187.76   PASS
# 701  MTB_anc  2631931  .   G   A  16730.76   PASS
# 702  MTB_anc  2631932  .   C   G  16726.76   PASS
# 703  MTB_anc  2631938  .   G   A  16954.76   PASS
# 704  MTB_anc  2631940  .   T   A  17702.02   PASS
# 705  MTB_anc  2631941  .   A   G  18265.76   PASS
# 706  MTB_anc  2631944  .   C   T  18276.76   PASS
# 763  MTB_anc  2960724  .   A   G    100.81   PASS
# 764  MTB_anc  2960726  .   A   T    101.90   PASS
# 765  MTB_anc  2960727  .   C   T    100.28   PASS
# 766  MTB_anc  2960731  .   C   G     58.88   PASS
# 767  MTB_anc  2960732  .   C   G     59.31   PASS
# 768  MTB_anc  2960736  .   A   G     59.65   PASS
# 769  MTB_anc  2960737  .   A   T     61.07   PASS
# 770  MTB_anc  2960739  .   C   T     59.86   PASS
#
#                                                   INFO  \
# 394  AC=1;AF=0.500;AN=2;BaseQRankSum=-2.507e+00;DP=...
# 395  AC=1;AF=0.500;AN=2;BaseQRankSum=-7.780e-01;DP=...
# 396  AC=1;AF=0.500;AN=2;BaseQRankSum=-2.656e+00;DP=...
# 397  AC=1;AF=0.500;AN=2;BaseQRankSum=-1.674e+00;DP=...
# 398  AC=1;AF=0.500;AN=2;BaseQRankSum=2.07;DP=71;Exc...
# 399  AC=1;AF=0.500;AN=2;BaseQRankSum=-2.933e+00;DP=...
# 400  AC=1;AF=0.500;AN=2;BaseQRankSum=-2.230e+00;DP=...
# 700  AC=1;AF=0.500;AN=2;BaseQRankSum=0.621;DP=79;Ex...
# 701  AC=1;AF=0.500;AN=2;BaseQRankSum=-2.400e+00;DP=...
# 702  AC=1;AF=0.500;AN=2;BaseQRankSum=-9.900e-01;DP=...
# 703  AC=1;AF=0.500;AN=2;BaseQRankSum=-2.546e+00;DP=...
# 704  AC=1;AF=0.500;AN=2;BaseQRankSum=0.833;DP=77;Ex...
# 705  AC=1;AF=0.500;AN=2;BaseQRankSum=3.50;DP=78;Exc...
# 706  AC=1;AF=0.500;AN=2;BaseQRankSum=-2.379e+00;DP=...
# 763  AC=1;AF=0.500;AN=2;BaseQRankSum=0.00;DP=6;Exce...
# 764  AC=1;AF=0.500;AN=2;BaseQRankSum=0.00;DP=6;Exce...
# 765  AC=1;AF=0.500;AN=2;BaseQRankSum=-6.230e-01;DP=...
# 766  AC=1;AF=0.500;AN=2;BaseQRankSum=0.00;DP=5;Exce...
# 767  AC=1;AF=0.500;AN=2;BaseQRankSum=0.00;DP=5;Exce...
# 768  AC=1;AF=0.500;AN=2;BaseQRankSum=0.00;DP=5;Exce...
# 769  AC=1;AF=0.500;AN=2;BaseQRankSum=0.524;DP=5;Exc...
# 770  AC=1;AF=0.500;AN=2;BaseQRankSum=0.00;DP=5;Exce...
#
#                         FORMAT  \
# 394  GT:AD:DP:GQ:PGT:PID:PL:PS
# 395  GT:AD:DP:GQ:PGT:PID:PL:PS
# 396  GT:AD:DP:GQ:PGT:PID:PL:PS
# 397  GT:AD:DP:GQ:PGT:PID:PL:PS
# 398  GT:AD:DP:GQ:PGT:PID:PL:PS
# 399  GT:AD:DP:GQ:PGT:PID:PL:PS
# 400  GT:AD:DP:GQ:PGT:PID:PL:PS
# 700  GT:AD:DP:GQ:PGT:PID:PL:PS
# 701  GT:AD:DP:GQ:PGT:PID:PL:PS
# 702  GT:AD:DP:GQ:PGT:PID:PL:PS
# 703  GT:AD:DP:GQ:PGT:PID:PL:PS
# 704  GT:AD:DP:GQ:PGT:PID:PL:PS
# 705  GT:AD:DP:GQ:PGT:PID:PL:PS
# 706  GT:AD:DP:GQ:PGT:PID:PL:PS
# 763  GT:AD:DP:GQ:PGT:PID:PL:PS
# 764  GT:AD:DP:GQ:PGT:PID:PL:PS
# 765  GT:AD:DP:GQ:PGT:PID:PL:PS
# 766  GT:AD:DP:GQ:PGT:PID:PL:PS
# 767  GT:AD:DP:GQ:PGT:PID:PL:PS
# 768  GT:AD:DP:GQ:PGT:PID:PL:PS
# 769  GT:AD:DP:GQ:PGT:PID:PL:PS
# 770  GT:AD:DP:GQ:PGT:PID:PL:PS
#
#                                                 sample   AC   af   AN    DP  \
# 394  0|1:59,10:69:99:0|1:1480174_C_G:242,0,2484:148...  1.0  0.5  2.0  69.0
# 395  0|1:60,10:70:99:0|1:1480174_C_G:239,0,2526:148...  1.0  0.5  2.0  70.0
# 396  0|1:58,10:68:99:0|1:1480174_C_G:239,0,2526:148...  1.0  0.5  2.0  68.0
# 397  0|1:59,10:69:99:0|1:1480174_C_G:233,0,2610:148...  1.0  0.5  2.0  69.0
# 398  0|1:61,10:71:99:0|1:1480174_C_G:227,0,2694:148...  1.0  0.5  2.0  71.0
# 399  0|1:61,9:70:99:0|1:1480174_C_G:233,0,2604:1480174  1.0  0.5  2.0  70.0
# 400  0|1:62,9:71:99:0|1:1480174_C_G:233,0,2604:1480174  1.0  0.5  2.0  71.0
# 700  0|1:48,31:79:99:0|1:2631929_C_G:1157,0,4997:26...  1.0  0.5  2.0  79.0
# 701  0|1:48,31:79:99:0|1:2631929_C_G:1199,0,4994:26...  1.0  0.5  2.0  79.0
# 702  0|1:48,31:79:99:0|1:2631929_C_G:1199,0,4994:26...  1.0  0.5  2.0  79.0
# 703  0|1:46,32:78:99:0|1:2631929_C_G:1202,0,4952:26...  1.0  0.5  2.0  78.0
# 766  2960724       2     4.0     1.0    0    1   5.0  0.800000  0.200000
# 767  2960724       2     4.0     1.0    0    1   5.0  0.800000  0.200000
# 768  2960724       2     4.0     1.0    0    1   5.0  0.800000  0.200000
# 769  2960724       2     4.0     1.0    0    1   5.0  0.800000  0.200000
# 770  2960724       2     4.0     1.0    0    1   5.0  0.800000  0.200000
#
#      window_10  window_20  window_30
# 394          3          7          9
# 395          4          7          9
# 396          4          7          9
# 397          4          7          9
# 398          4          7          9
# 399          4          7          9
# 400          4          7          9
# 700          4          7          7
# 701          4          7          7
# 702          4          7          7
# 703          4          7          7
# 704          4          7          7
# 705          4          7          7
# 706          4          7          7
# 763          5          8          8
# 764          5          8          8
# 765          5          8          8
# 766          5          8          8
# 767          5          8          8
# 768          5          8          8
# 769          5          8          8
# 770          5          8          8

# %%
def bed_to_dict(bed_file):
    dict_range_positions = {}
    with open(bed_file, 'r') as f:
        for line_number, line in enumerate(f):
            line_split = line.split(None) #This split by any blank character
            start = line_split[1]
            end = line_split[2]
            if len(line_split) == 3 and start.isdigit() and end.isdigit():
                start = int(start)
                end = int(end)
                dict_range_positions[start] = end
            else:
                if line_number != 0:
                    print("This file is not in bed format")
                    sys.exit(1)
                
    return dict_range_positions

# %%
dict_test = bed_to_dict(bed)

# %%
def annotate_bed(bed_file, vcf_df, tag):
    dict_position = bed_to_dict(bed_file)
    all_positions = vcf_df.POS.tolist()
    for start, end in dict_position.items():
        for pos in all_positions:
            index = vcf_df.index[vcf_df["POS"] == pos][0]
            if pos >= start and pos <= end:
                vcf_df.loc[index, tag] = True
            else:
                vcf_df.loc[index, tag] = False

# %%
def annotate_bed(bed_file, pos):
    dict_position = bed_to_dict(bed_file)
    for start, end in dict_position.items():
        if pos >= start and pos <= end:
            return True
        else:
            return False
#CREATE A LIST?????

# %%
annotate_bed(bed, 475816)
# Out:
# False

# %%
#df['Is_repeat'] = df.apply(annotate_bed(bed, row), axis=1)

# %%
df['Is_repeat'] = df['POS'].apply(lambda x: annotate_bed(bed,x))

# %%
df[df.Is_repeat == True]
# Out:
# Empty DataFrame
# Columns: [#CHROM, POS, ID, REF, ALT, QUAL, FILTER, INFO, FORMAT, sample, AC, af, AN, DP, ExcessHet, FS, InbreedingCoeff, MQ, QD, SOR, GT, AD, GQ, PL, BaseQRankSum, MQRankSum, ReadPosRankSum, PGT, PID, PS, len_AD, REF_AD, ALT_AD, gt0, gt1, dp, aF, AF, Is_polymorphic, Is_repeat]
# Index: []

# %%
df[df.Is_polymorphic == False]
# Out:
#        #CHROM      POS ID REF ALT       QUAL FILTER  \
# 0     MTB_anc     1277  .   C   A   12726.43   PASS
# 1     MTB_anc     2532  .   C   T   71031.72   PASS
# 2     MTB_anc     9143  .   C   T  128501.72   PASS
# 3     MTB_anc    13460  .   G   A  129292.72   PASS
# 4     MTB_anc    14251  .   G   A   68528.18   PASS
# 5     MTB_anc    14401  .   G   A  116385.72   PASS
# 6     MTB_anc    15117  .   G   C  188675.72   PASS
# 7     MTB_anc    21819  .   C   A   12940.25   PASS
# 1143  MTB_anc  4408923  .   T   C  119508.72   PASS
#
#                                                    INFO  \
# 0     AC=2;AF=1.00;AN=2;DP=187;ExcessHet=0.0006;FS=0...
# 1     AC=2;AF=1.00;AN=2;BaseQRankSum=1.83;DP=86;Exce...
# 2     AC=2;AF=1.00;AN=2;DP=57;ExcessHet=3.0103;FS=0....
# 3     AC=2;AF=1.00;AN=2;BaseQRankSum=1.78;DP=45;Exce...
# 4     AC=2;AF=1.00;AN=2;BaseQRankSum=-1.716e+00;DP=3...
# 5     AC=2;AF=1.00;AN=2;BaseQRankSum=-1.715e+00;DP=5...
# 6     AC=2;AF=1.00;AN=2;BaseQRankSum=1.82;DP=85;Exce...
# 7     AC=2;AF=1.00;AN=2;DP=5;ExcessHet=3.0103;FS=0.0...
# 8     AC=2;AF=1.00;AN=2;BaseQRankSum=2.40;DP=39;Exce...
# 9     AC=2;AF=1.00;AN=2;BaseQRankSum=-1.160e+00;DP=3...
# 10    AC=2;AF=1.00;AN=2;DP=90;ExcessHet=0.0000;FS=0....
# 11    AC=2;AF=1.00;AN=2;BaseQRankSum=1.76;DP=88;Exce...
# 12    AC=2;AF=1.00;AN=2;BaseQRankSum=-1.721e+00;DP=4...
# 13    AC=2;AF=1.00;AN=2;DP=21;ExcessHet=0.0006;FS=0....
# 14    AC=2;AF=1.00;AN=2;BaseQRankSum=1.78;DP=29;Exce...
# 15    AC=2;AF=1.00;AN=2;BaseQRankSum=0.668;DP=34;Exc...
# 16    AC=2;AF=1.00;AN=2;BaseQRankSum=1.73;DP=61;Exce...
# 17    AC=2;AF=1.00;AN=2;BaseQRankSum=-1.814e+00;DP=3...
# 18    AC=2;AF=1.00;AN=2;DP=47;ExcessHet=0.0000;FS=0....
# 19    AC=2;AF=1.00;AN=2;DP=84;ExcessHet=0.0000;FS=0....
# 20    AC=2;AF=1.00;AN=2;DP=177;ExcessHet=0.0000;FS=0...
# 21    AC=2;AF=1.00;AN=2;BaseQRankSum=1.78;DP=131;Exc...
# 22    AC=2;AF=1.00;AN=2;DP=83;ExcessHet=0.0006;FS=0....
# 23    AC=2;AF=1.00;AN=2;DP=85;ExcessHet=0.0006;FS=0....
# 24    AC=2;AF=1.00;AN=2;DP=164;ExcessHet=0.0000;FS=0...
# 25    AC=2;AF=1.00;AN=2;DP=41;ExcessHet=0.0006;FS=0....
# 26    AC=2;AF=1.00;AN=2;DP=28;ExcessHet=0.0006;FS=0....
# 27    AC=2;AF=1.00;AN=2;BaseQRankSum=1.83;DP=19;Exce...
# 28    AC=2;AF=1.00;AN=2;DP=21;ExcessHet=0.0006;FS=0....
# 29    AC=2;AF=1.00;AN=2;DP=78;ExcessHet=3.0103;FS=0....
# ...                                                 ...
# 1114  AC=2;AF=1.00;AN=2;DP=18;ExcessHet=3.0103;FS=0....
# 1115  AC=2;AF=1.00;AN=2;BaseQRankSum=1.79;DP=71;Exce...
# 1116  AC=2;AF=1.00;AN=2;BaseQRankSum=1.77;DP=110;Exc...
# 1117  AC=2;AF=1.00;AN=2;DP=38;ExcessHet=3.0103;FS=0....
# 1118  AC=2;AF=1.00;AN=2;BaseQRankSum=1.33;DP=82;Exce...
# 1119  AC=2;AF=1.00;AN=2;DP=55;ExcessHet=0.0030;FS=0....
# 1120  AC=2;AF=1.00;AN=2;BaseQRankSum=1.47;DP=30;Exce...
# 1121  AC=2;AF=1.00;AN=2;BaseQRankSum=2.00;DP=12;Exce...
# 1122  AC=2;AF=1.00;AN=2;BaseQRankSum=1.76;DP=58;Exce...
# 1123  AC=2;AF=1.00;AN=2;DP=86;ExcessHet=3.0103;FS=0....
# 1124  AC=2;AF=1.00;AN=2;DP=71;ExcessHet=3.0103;FS=0....
# 1125  AC=2;AF=1.00;AN=2;DP=39;ExcessHet=0.0000;FS=0....
# 1126  AC=2;AF=1.00;AN=2;BaseQRankSum=-1.753e+00;DP=5...
# 1127  AC=2;AF=1.00;AN=2;DP=77;ExcessHet=3.0103;FS=0....
# 1128  AC=2;AF=1.00;AN=2;BaseQRankSum=-1.834e+00;DP=8...
# 1129  AC=2;AF=1.00;AN=2;DP=40;ExcessHet=0.0006;FS=0....
# 1130  AC=2;AF=1.00;AN=2;BaseQRankSum=1.76;DP=12;Exce...
# 1131  AC=2;AF=1.00;AN=2;DP=26;ExcessHet=3.0103;FS=0....
# 1132  AC=2;AF=1.00;AN=2;BaseQRankSum=1.77;DP=22;Exce...
# 1133  AC=2;AF=1.00;AN=2;BaseQRankSum=1.79;DP=48;Exce...
# 1134  AC=2;AF=1.00;AN=2;BaseQRankSum=0.409;DP=48;Exc...
# 1135  AC=2;AF=1.00;AN=2;DP=33;ExcessHet=0.0006;FS=0....
# 1136  AC=2;AF=1.00;AN=2;BaseQRankSum=1.95;DP=45;Exce...
# 1137  AC=2;AF=1.00;AN=2;BaseQRankSum=2.11;DP=30;Exce...
# 1138  AC=2;AF=1.00;AN=2;DP=35;ExcessHet=3.0103;FS=0....
# 1139  AC=2;AF=1.00;AN=2;BaseQRankSum=1.71;DP=20;Exce...
# 1140  AC=2;AF=1.00;AN=2;BaseQRankSum=-1.162e+00;DP=5...
# 1141  AC=2;AF=1.00;AN=2;BaseQRankSum=1.77;DP=48;Exce...
# 1142  AC=2;AF=1.00;AN=2;BaseQRankSum=1.46;DP=44;Exce...
# 1143  AC=2;AF=1.00;AN=2;BaseQRankSum=1.83;DP=44;Exce...
#
#                          FORMAT  \
# 0                GT:AD:DP:GQ:PL
# 1                GT:AD:DP:GQ:PL
# 2                GT:AD:DP:GQ:PL
# 3                GT:AD:DP:GQ:PL
# 4                GT:AD:DP:GQ:PL
# 5                GT:AD:DP:GQ:PL
# 6                GT:AD:DP:GQ:PL
# 7                GT:AD:DP:GQ:PL
# 8                GT:AD:DP:GQ:PL
# 9                GT:AD:DP:GQ:PL
# 10               GT:AD:DP:GQ:PL
# 11               GT:AD:DP:GQ:PL
# 12               GT:AD:DP:GQ:PL
# 13               GT:AD:DP:GQ:PL
# 14               GT:AD:DP:GQ:PL
# 15               GT:AD:DP:GQ:PL
# 16               GT:AD:DP:GQ:PL
# 2     2071,170,0           NaN        NaN             NaN  NaN          NaN
# 3     1791,135,0         1.780       0.00           0.919  NaN          NaN
# 4      1174,98,0        -1.716       0.00           0.067  NaN          NaN
# 5     1964,175,0        -1.715       0.00           2.250  NaN          NaN
# 6     3527,256,0         1.820       0.00          -0.836  NaN          NaN
# 7       198,15,0           NaN        NaN             NaN  NaN          NaN
# 8     1641,117,0         2.400       0.00           1.350  NaN          NaN
# 9      1264,99,0        -1.160       0.00          -0.530  NaN          NaN
# 10    3263,270,0           NaN        NaN             NaN  NaN          NaN
# 11    3386,263,0         1.760       0.00           0.578  NaN          NaN
# 12    1386,123,0        -1.721       0.00           1.140  NaN          NaN
# 13      912,63,0           NaN        NaN             NaN  NaN          NaN
# 14     1074,87,0         1.780       7.68          -1.256  NaN          NaN
# 15    1236,102,0         0.668       0.00           1.410  NaN          NaN
# 16    2317,183,0         1.730       0.00           0.815  NaN          NaN
# 17     1326,71,0        -1.814       0.00          -0.222  NaN          NaN
# 18    1763,140,0           NaN        NaN             NaN  NaN          NaN
# 19    3061,252,0           NaN        NaN             NaN  NaN          NaN
# 20    6301,530,0           NaN        NaN             NaN  NaN          NaN
# 21    4922,392,0         1.780       0.00          -1.032  NaN          NaN
# 22    3780,253,0           NaN        NaN             NaN  NaN          NaN
# 23    3479,256,0           NaN        NaN             NaN  NaN          NaN
# 24    6169,491,0           NaN        NaN             NaN  NaN          NaN
# 25    1504,123,0           NaN        NaN             NaN  NaN          NaN
# 26     1041,84,0           NaN        NaN             NaN  NaN          NaN
# 27      821,57,0         1.830       0.00           0.668  NaN          NaN
# 28      691,62,0           NaN        NaN             NaN  NaN          NaN
# 29    2882,233,0           NaN        NaN             NaN  NaN          NaN
# ...          ...           ...        ...             ...  ...          ...
# 1114    703,54,0           NaN        NaN             NaN  NaN          NaN
# 1115  2830,213,0         1.790       0.00           0.867  NaN          NaN
# 1116  4138,330,0         1.770       0.00           1.720  NaN          NaN
# 1117  1557,113,0           NaN        NaN             NaN  NaN          NaN
# 1118  3145,246,0         1.330       0.00           1.540  NaN          NaN
# 1119  2043,164,0           NaN        NaN             NaN  NaN          NaN
# 1120   1165,90,0         1.470       0.00           1.620  NaN          NaN
# 1121    410,33,0         2.000       0.00           1.150  NaN          NaN
# 1122  2173,165,0         1.760       0.00           0.461  NaN          NaN
# 1123  3245,258,0           NaN        NaN             NaN  NaN          NaN
# 1124  2712,212,0           NaN        NaN             NaN  NaN          NaN
# 1125  1667,117,0           NaN        NaN             NaN  NaN          NaN
# 1126  1880,153,0        -1.753       0.00          -0.979  NaN          NaN
# 1127  3049,231,0           NaN        NaN             NaN  NaN          NaN
# 1128  2913,204,0        -1.834       0.00          -0.495  NaN          NaN
# 1129  1405,120,0           NaN        NaN             NaN  NaN          NaN
# 1130    474,36,0         1.760       0.00          -0.509  NaN          NaN
# 1131    994,78,0           NaN        NaN             NaN  NaN          NaN
# 1132    680,65,0         1.770       0.00           1.710  NaN          NaN
# 1133  1662,144,0         1.790       0.00          -0.802  NaN          NaN
# 1134  1620,144,0         0.409       0.00           0.837  NaN          NaN
# 1135   1135,99,0           NaN        NaN             NaN  NaN          NaN
# 1136  1750,135,0         1.950       0.00           1.590  NaN          NaN
# 1137   1120,90,0         2.110       0.00           1.630  NaN          NaN
# 1138  1442,105,0           NaN        NaN             NaN  NaN          NaN
# 1139    755,60,0         1.710       0.00           1.390  NaN          NaN
# 1140  1895,150,0        -1.162       0.00           0.826  NaN          NaN
# 1141  1888,144,0         1.770       0.00          -0.207  NaN          NaN
# 1142  1962,132,0         1.460       0.00           1.740  1|1  4408920_G_A
# 1143  1962,132,0         1.830       0.00           1.730  1|1  4408920_G_A
#
#            PS  len_AD  REF_AD  ALT_AD  gt0  gt1     dp        aF        AF  \
# 0         NaN       2     0.0   187.0    1    1  187.0  0.000000  1.000000
# 1         NaN       2     0.0    86.0    1    1   86.0  0.000000  1.000000
# 2         NaN       2     0.0    57.0    1    1   57.0  0.000000  1.000000
# 3         NaN       2     0.0    45.0    1    1   45.0  0.000000  1.000000
# 4         NaN       2     0.0    33.0    1    1   33.0  0.000000  1.000000
# 5         NaN       2     0.0    59.0    1    1   59.0  0.000000  1.000000
# 6         NaN       2     0.0    85.0    1    1   85.0  0.000000  1.000000
# 7         NaN       2     0.0     5.0    1    1    5.0  0.000000  1.000000
# 8         NaN       2     0.0    39.0    1    1   39.0  0.000000  1.000000
# 9         NaN       2     0.0    33.0    1    1   33.0  0.000000  1.000000
# 10        NaN       2     0.0    90.0    1    1   90.0  0.000000  1.000000
# 11        NaN       2     0.0    88.0    1    1   88.0  0.000000  1.000000
# 12        NaN       2     0.0    41.0    1    1   41.0  0.000000  1.000000
# 13        NaN       2     0.0    21.0    1    1   21.0  0.000000  1.000000
# 14        NaN       2     0.0    29.0    1    1   29.0  0.000000  1.000000
# 15        NaN       2     0.0    34.0    1    1   34.0  0.000000  1.000000
# 16        NaN       2     0.0    61.0    1    1   61.0  0.000000  1.000000
# 17        NaN       2     1.0    38.0    1    1   39.0  0.025641  0.974359
# 18        NaN       2     0.0    47.0    1    1   47.0  0.000000  1.000000
# 19        NaN       2     0.0    84.0    1    1   84.0  0.000000  1.000000
# 20        NaN       2     0.0   177.0    1    1  177.0  0.000000  1.000000
# 21        NaN       2     0.0   131.0    1    1  131.0  0.000000  1.000000
# 22        NaN       2     0.0    83.0    1    1   83.0  0.000000  1.000000
# 23        NaN       2     0.0    85.0    1    1   85.0  0.000000  1.000000
# 24        NaN       2     0.0   164.0    1    1  164.0  0.000000  1.000000
# 25        NaN       2     0.0    41.0    1    1   41.0  0.000000  1.000000
# 26        NaN       2     0.0    28.0    1    1   28.0  0.000000  1.000000
# 27        NaN       2     0.0    19.0    1    1   19.0  0.000000  1.000000
# 28        NaN       2     0.0    21.0    1    1   21.0  0.000000  1.000000
# 29        NaN       2     0.0    78.0    1    1   78.0  0.000000  1.000000
# ...       ...     ...     ...     ...  ...  ...    ...       ...       ...
# 1114      NaN       2     0.0    18.0    1    1   18.0  0.000000  1.000000
# 1115      NaN       2     0.0    71.0    1    1   71.0  0.000000  1.000000
# 1116      NaN       2     0.0   110.0    1    1  110.0  0.000000  1.000000
# 1117      NaN       2     0.0    38.0    1    1   38.0  0.000000  1.000000
# 1118      NaN       2     0.0    82.0    1    1   82.0  0.000000  1.000000
# 1119      NaN       2     0.0    55.0    1    1   55.0  0.000000  1.000000
# 1120      NaN       2     0.0    30.0    1    1   30.0  0.000000  1.000000
# 1121      NaN       2     0.0    12.0    1    1   12.0  0.000000  1.000000
# 1122      NaN       2     1.0    57.0    1    1   58.0  0.017241  0.982759
# 1123      NaN       2     0.0    86.0    1    1   86.0  0.000000  1.000000
# 1124      NaN       2     0.0    71.0    1    1   71.0  0.000000  1.000000
# 1125      NaN       2     0.0    39.0    1    1   39.0  0.000000  1.000000
# 1126      NaN       2     0.0    51.0    1    1   51.0  0.000000  1.000000
# 1127      NaN       2     0.0    77.0    1    1   77.0  0.000000  1.000000
# 1128      NaN       2     1.0    83.0    1    1   84.0  0.011905  0.988095
# 1129      NaN       2     0.0    40.0    1    1   40.0  0.000000  1.000000
# 1130      NaN       2     0.0    12.0    1    1   12.0  0.000000  1.000000
# 1131      NaN       2     0.0    26.0    1    1   26.0  0.000000  1.000000
# 1132      NaN       2     0.0    22.0    1    1   22.0  0.000000  1.000000
# 1133      NaN       2     0.0    48.0    1    1   48.0  0.000000  1.000000
# 1134      NaN       2     0.0    48.0    1    1   48.0  0.000000  1.000000
# 1135      NaN       2     0.0    33.0    1    1   33.0  0.000000  1.000000
# 1136      NaN       2     0.0    45.0    1    1   45.0  0.000000  1.000000
# 1137      NaN       2     0.0    30.0    1    1   30.0  0.000000  1.000000
# 1138      NaN       2     0.0    35.0    1    1   35.0  0.000000  1.000000
# 1139      NaN       2     0.0    20.0    1    1   20.0  0.000000  1.000000
# 1140      NaN       2     0.0    50.0    1    1   50.0  0.000000  1.000000
# 1141      NaN       2     0.0    48.0    1    1   48.0  0.000000  1.000000
# 1142  4408920       2     0.0    44.0    1    1   44.0  0.000000  1.000000
# 1143  4408920       2     0.0    44.0    1    1   44.0  0.000000  1.000000
#
#       Is_polymorphic
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# 5              False
# 6              False
# 7              False
# 8              False
# 9              False
# 10             False
# 11             False
# 12             False
# 13             False
# 14             False
# 15             False
# 16             False
# 17             False
# 18             False
# 19             False
# 20             False
# 21             False
# 22             False
# 23             False
# 24             False
# 25             False
# 26             False
# 27             False
# 28             False
# 29             False
# ...              ...
# 1114           False
# 1115           False
# 1116           False
# 1117           False
# 1118           False
# 1119           False
# 1120           False
# 1121           False
# 1122           False
# 1123           False
# 1124           False
# 1125           False
# 1126           False
# 1127           False
# 1128           False
# 1129           False
# 1130           False
# 1131           False
# 1132           False
# 1133           False
# 1134           False
# 1135           False
# 1136           False
# 1137           False
# 1138           False
# 1139           False
# 1140           False
# 1141           False
# 1142           False
# 1143           False
#
# [1144 rows x 39 columns]

# %%
for start,end in dict_recombination_positions.items():
    start = int(start)
    end = int(end)
    
    for pos in common_snp_list:
        if int(pos) >= start and pos <= end:
            print(str(count) + ": position " + str(pos) + " is recombinant in common file between " + str(start) + " and " + str(end))
            count = count +1
