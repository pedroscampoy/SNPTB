# %%
import pandas as pd
import re
import sys

# %%
pd.set_option('display.max_columns', None)

# %%
abr_list = "../../annotation/resistance/Resistance_Report_snp_with_positions_v2019-01_complete.tsv"

# %%
# %%bash
# head -n 2 ../../annotation/resistance/Resistance_Report_snp_with_positions_v2019-01_complete.tsv
# Out:
# drug	gene	iso_tested	iso_w_mut	iso_excluded	denominator	nuchange	aachange	TP	FP	TN	FN	Sensitivity	Specificity	PPV	NPV	ACC	LR+	p-value	confidence_low	confidence_upp	Bonferroni_adjusted	FDR_adjusted	gene_pos	REF	ALT	Gene	is_upstream	Gene_id	start	end	strand	POS
# AMIKACIN	rrs	1229	3	3	1226	1050C>T		2	1	916	307	0.0065	0.9989	0.6667	0.749	0.7488	5.93527	0.158321071658866	0.465520465996814	inf	1.0	0.803966014708151	1050	C	T	rrs		Rvnr01	1471846	1473382	+	1472895

# %%
df = pd.read_csv(abr_list, sep="\t")

# %%
df.head()
# Out:
#        drug gene  iso_tested  iso_w_mut  iso_excluded  denominator nuchange  \
# 0  AMIKACIN  rrs        1229          3             3         1226  1050C>T
# 1  AMIKACIN  rrs        1229          1             3         1226  1125C>T
# 2  AMIKACIN  rrs        1229          1             3         1226  1148G>A
# 3  AMIKACIN  rrs        1229          2             3         1226  1190G>A
# 4  AMIKACIN  rrs        1229          1             4         1225  1223A>G
#
#   aachange  TP  FP   TN   FN  Sensitivity  Specificity     PPV     NPV  \
# 0      NaN   2   1  916  307       0.0065       0.9989  0.6667  0.7490
# 1      NaN   0   1  916  309       0.0000       0.9989  0.0000  0.7478
# 2      NaN   0   1  916  309       0.0000       0.9989  0.0000  0.7478
# 3      NaN   1   1  916  308       0.0032       0.9989  0.5000  0.7484
# 4      NaN   1   0  916  308       0.0032       1.0000  1.0000  0.7484
#
#       ACC           LR+   p-value  confidence_low  confidence_upp  \
# 0  0.7488       5.93527  0.158321        0.465520             inf
# 1  0.7471       0.00000  0.747961        0.000000       56.215319
# 2  0.7471       0.00000  0.747961        0.000000       56.215319
# 3  0.7480       2.96764  0.440708        0.077161             inf
# 4  0.7486  999999.00000  0.252245        0.156151             inf
#
#    Bonferroni_adjusted  FDR_adjusted  gene_pos REF ALT Gene is_upstream  \
# 0                  1.0      0.803966      1050   C   T  rrs         NaN
# 1                  1.0      0.803966      1125   C   T  rrs         NaN
# 2                  1.0      0.803966      1148   G   A  rrs         NaN
# 3                  1.0      0.803966      1190   G   A  rrs         NaN
# 4                  1.0      0.803966      1223   A   G  rrs         NaN
#
#   Gene_id    start      end strand      POS
# 0  Rvnr01  1471846  1473382      +  1472895
# 1  Rvnr01  1471846  1473382      +  1472970
# 2  Rvnr01  1471846  1473382      +  1472993
# 3  Rvnr01  1471846  1473382      +  1473035
# 4  Rvnr01  1471846  1473382      +  1473068

# %%
df['res_gene']=df['gene'] + " (" + df['drug'] + ")"

# %%
df['CHROM']= "CHROM"

# %%
df.head()
# Out:
#        drug gene  iso_tested  iso_w_mut  iso_excluded  denominator nuchange  \
# 0  AMIKACIN  rrs        1229          3             3         1226  1050C>T
# 1  AMIKACIN  rrs        1229          1             3         1226  1125C>T
# 2  AMIKACIN  rrs        1229          1             3         1226  1148G>A
# 3  AMIKACIN  rrs        1229          2             3         1226  1190G>A
# 4  AMIKACIN  rrs        1229          1             4         1225  1223A>G
#
#   aachange  TP  FP   TN   FN  Sensitivity  Specificity     PPV     NPV  \
# 0      NaN   2   1  916  307       0.0065       0.9989  0.6667  0.7490
# 1      NaN   0   1  916  309       0.0000       0.9989  0.0000  0.7478
# 2      NaN   0   1  916  309       0.0000       0.9989  0.0000  0.7478
# 3      NaN   1   1  916  308       0.0032       0.9989  0.5000  0.7484
# 4      NaN   1   0  916  308       0.0032       1.0000  1.0000  0.7484
#
#       ACC           LR+   p-value  confidence_low  confidence_upp  \
# 0  0.7488       5.93527  0.158321        0.465520             inf
# 1  0.7471       0.00000  0.747961        0.000000       56.215319
# 2  0.7471       0.00000  0.747961        0.000000       56.215319
# 3  0.7480       2.96764  0.440708        0.077161             inf
# 4  0.7486  999999.00000  0.252245        0.156151             inf
#
#    Bonferroni_adjusted  FDR_adjusted  gene_pos REF ALT Gene is_upstream  \
# 0                  1.0      0.803966      1050   C   T  rrs         NaN
# 1                  1.0      0.803966      1125   C   T  rrs         NaN
# 2                  1.0      0.803966      1148   G   A  rrs         NaN
# 3                  1.0      0.803966      1190   G   A  rrs         NaN
# 4                  1.0      0.803966      1223   A   G  rrs         NaN
#
#   Gene_id    start      end strand      POS        res_gene  CHROM
# 0  Rvnr01  1471846  1473382      +  1472895  rrs (AMIKACIN)  CHROM
# 1  Rvnr01  1471846  1473382      +  1472970  rrs (AMIKACIN)  CHROM
# 2  Rvnr01  1471846  1473382      +  1472993  rrs (AMIKACIN)  CHROM
# 3  Rvnr01  1471846  1473382      +  1473035  rrs (AMIKACIN)  CHROM
# 4  Rvnr01  1471846  1473382      +  1473068  rrs (AMIKACIN)  CHROM

# %%
df['gene'].value_counts().index.tolist()
# Out:
# ['rpoB',
#  'rpoC',
#  'mas',
#  'rrs',
#  'katG',
#  'embB',
#  'pncA',
#  'ppsC',
#  'gyrA',
#  'ppsD',
#  'gidB',
#  'embA',
#  'gyrB',
#  'ponA1',
#  'rpoA',
#  'embC',
#  'ethA',
#  'mymA',
#  'eccC5',
#  'mshA',
#  'ndh',
#  'aftA',
#  'mshC',
#  'ubiA',
#  'clpC1',
#  'kasA',
#  'gpsI',
#  'nudC',
#  'tap',
#  'embR',
#  'inhA',
#  'ppsA upstream',
#  'rpsA',
#  'Rv0565c',
#  'Rv3169',
#  'Rv0191',
#  'Rv2731',
#  'fabG1',
#  'nat',
#  'inbR',
#  'fabG1 upstream',
#  'tap upstream',
#  'mshB',
#  'eccB5',
#  'whiB7 upstream',
#  'Rv1667c',
#  'sigI',
#  'Rv3008',
#  'Rv1667c upstream',
#  'mmaA3',
#  'rrl',
#  'rpoB upstream',
#  'eis',
#  'proZ upstream',
#  'ahpC',
#  'ponA1 upstream',
#  'furA',
#  'proZ',
#  'mas upstream',
#  'rpsL upstream',
#  'mymA upstream',
#  'gyrB upstream',
#  'ethR',
#  'embA upstream',
#  'rpsL',
#  'panD',
#  'ahpC upstream',
#  'tlyA',
#  'eis upstream',
#  'whiB7',
#  'mshB upstream',
#  'ndh upstream',
#  'gpsI upstream',
#  'rpoA upstream',
#  'rpsA upstream',
#  'nat upstream',
#  'eccB5 upstream',
#  'katG upstream',
#  'gyrA upstream',
#  'furA upstream',
#  'pncA upstream',
#  'alr upstream',
#  'rrs upstream',
#  'mshC upstream',
#  'alr',
#  'cycA',
#  'mmaA3 upstream',
#  'embR upstream',
#  'ethA upstream',
#  'gidB upstream',
#  'sigI upstream',
#  'pykA',
#  'nudC upstream',
#  'ald',
#  'mshA upstream',
#  'clpC1 upstream',
#  'rrl upstream',
#  'inbR upstream',
#  'Rv0565c upstream',
#  'Rv0191 upstream',
#  'ald upstream',
#  'inhA upstream',
#  'pykA upstream',
#  'rpoC upstream',
#  'Rv3008 upstream',
#  'rplC',
#  'ddlA']

# %%
df_grouped = df.groupby('gene', as_index=False)

# %%
final_bed = df_grouped.first()[['CHROM','start','end', 'res_gene']]

# %%
final_bed.head()
# Out:
#    CHROM    start      end                        res_gene
# 0  CHROM   222289   223530           Rv0191 (PYRAZINAMIDE)
# 1  CHROM   222289   223530  Rv0191 upstream (PYRAZINAMIDE)
# 2  CHROM   656010   657470           Rv0565c (ETHIONAMIDE)
# 3  CHROM   656010   657470  Rv0565c upstream (ETHIONAMIDE)
# 4  CHROM  1893578  1894230          Rv1667c (PYRAZINAMIDE)

# %%
final_bed.to_csv('../../annotation/resistance/drug_related_init.bed', sep='\t', index=False)

# %%
#This file will be manually modified in upstream regions and header
